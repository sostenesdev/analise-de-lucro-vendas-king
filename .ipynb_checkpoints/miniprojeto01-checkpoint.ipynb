# %%
#- Encontre a cidade de cada imóvel;
#- Calcule o preço por área de imóvel;
#- Calcule o lucro/ perda de investimento caso o imóvel seja vendido mais de uma vez naquele período.



import pandas as pd
import folium as flm
import matplotlib.pyplot as plt
import seaborn as sns

Ts = pd.read_csv('kc_house_data.csv', squeeze = True)
Ts.isnull().sum()
dfs = pd.DataFrame(Ts)

dfs.head()
#counts = dfs['id'].value_counts()

#dfs[dfs.apply(lambda x: counts[x['id']] > 1.0, axis=1)]

for i in range(len(dfs)) :
  print(dfs.loc[i, "id"], dfs.loc[i, "price"])

# %%
#- Encontre a cidade de cada imóvel;
#- Calcule o preço por área de imóvel;
#- Calcule o lucro/ perda de investimento caso o imóvel seja vendido mais de uma vez naquele período.



import pandas as pd
import folium as flm
import matplotlib.pyplot as plt
import seaborn as sns

Ts = pd.read_csv('kc_house_data.csv', squeeze = True)
Ts.isnull().sum()
dfs = pd.DataFrame(Ts)

dfs.head()
#counts = dfs['id'].value_counts()

#dfs[dfs.apply(lambda x: counts[x['id']] > 1.0, axis=1)]

for i in range(len(df)) :
  print(df.loc[i, "id"], df.loc[i, "price"])



#dfs['price'].hist(bins = 10, range=[ 0, 750000], facecolor='gray', align='mid')

# %%
dfs.sort_values(by=['price'],ascending= [True])

# %%
#dfs['quintal'] = dfs['sqft_lot'] - dfs['sqft_living']

dfs.sort_values(by=['quintal','price','waterfront'],ascending= [False,True,True])

dfs.sort_values(by=['quintal','price','waterfront'],ascending= [False,True,True])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1719   1020069017  20150327T000000   700000.0         4       1.00
# 17319  3326079016  20150504T000000   190000.0         2       1.00
# 7647   2623069031  20140521T000000   542500.0         5       3.25
# 7769   2323089009  20150119T000000   855000.0         4       3.50
# 4441   3626079040  20140730T000000   790000.0         2       3.00
# ...           ...              ...        ...       ...        ...
# 20703  5167000140  20140711T000000  1480000.0         3       3.25
# 18535  3667500015  20140925T000000   770000.0         4       3.50
# 21372  6169901185  20140520T000000   490000.0         5       3.50
# 3452   2559950110  20150422T000000  1234570.0         2       2.50
# 15743  9828702895  20141022T000000   700000.0         4       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 1719          1300   1651359     1.0           0     3  ...        1300
# ...

# %%
#dfs.head()
#dfs.filter(items=['lat','long']).head()

#Retorna o dataFrame filtrando através da expressão
#dfs[dfs.apply(lambda x: x['floors'] == 1.0, axis=1)]

#dfs['price'].hist(bins = 100, range=[ 0, 750000], facecolor='gray', align='mid')

#dfs['sqft_lot'].hist(bins = 100, range=[ 0, 100000], facecolor='blue', align='mid')

# %%
coordenadas = []
mapa = flm.Map(location=[47.58766, -121.83072], zoom_start=5,tiles='Stamen Terrain')
dfs.head().apply(lambda row: flm.Marker(location=[row['lat'],row['long']],popup="Timberline Lodge",icon=flm.Icon(color="green"),).add_to(mapa),axis=1)
#dfs.apply(lambda row: flm.Marker(location=[row['lat'],row['long']],popup="Timberline Lodge",icon=flm.Icon(color="green"),).add_to(mapa),axis=1)
mapa
import pandas as pd
import folium as flm
Ts = pd.read_csv('kc_house_data.csv')
dfs = pd.DataFrame(Ts)
#dfs.head()
#dfs.filter(items=['lat','long']).head()

#Retorna o dataFrame filtrando através da expressão
#dfs[dfs.apply(lambda x: x['floors'] == 1.0, axis=1)]
coordenadas = []
mapa = flm.Map(location=[47.58766, -121.83072], zoom_start=5,tiles='Stamen Terrain')
dfs.head().apply(lambda row: flm.Marker(location=[row['lat'],row['long']],popup="Timberline Lodge",icon=flm.Icon(color="green"),).add_to(mapa),axis=1)
#dfs.apply(lambda row: flm.Marker(location=[row['lat'],row['long']],popup="Timberline Lodge",icon=flm.Icon(color="green"),).add_to(mapa),axis=1)
mapa
